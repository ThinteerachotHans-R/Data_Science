# %% [markdown]
# # Create dataframe from reading differnt formats

# %% [markdown]
# Ref: https://sparkbyexamples.com/pandas/

# %%
#import libraries
import pandas as pd

# %% [markdown]
# ## Mount my Gdirve

# %%
from google.colab import drive
ROOT = "/content/GDrive"
drive.mount(ROOT)
# Out:
# Mounted at /content/GDrive

# %% [markdown]
# ## Excel format

# %%
# Read Excel file
excel_path = "/content/GDrive/MyDrive/COS3302/data_files/courses.XLSX"
df = pd.read_excel(excel_path)
print(df)
# Out:
#   Courses     Fee Duration   Discount
# 0    Spark  25000   50 Days       2000
# 1   Pandas  20000   35 Days       1000
# 2     Java  15000       NaN        800
# 3   Python  15000   30 Days        500
# 4      PHP  18000   30 Days        800

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Read excel by considering first row as data
columns = ["courses","course_fee","course_duration","course_discount"]
df2 = pd.read_excel(excel_path, header=0, names = columns)
df2
# Out:
#   courses  course_fee course_duration  course_discount
# 0   Spark       25000         50 Days             2000
# 1  Pandas       20000         35 Days             1000
# 2    Java       15000             NaN              800
# 3  Python       15000         30 Days              500
# 4     PHP       18000         30 Days              800

# %%
# Read excel by setting column as index
df2 = pd.read_excel(excel_path, index_col=0)
print(df2)
# Out:
#             Fee Duration   Discount
# Courses
# Spark     25000   50 Days       2000
# Pandas    20000   35 Days       1000
# Java      15000       NaN        800
# Python    15000   30 Days        500
# PHP       18000   30 Days        800

# %%
# Read specific excel sheet
df = pd.read_excel(excel_path, sheet_name="Sheet1")
print(df)
# Out:
#   Courses     Fee Duration   Discount
# 0    Spark  25000   50 Days       2000
# 1   Pandas  20000   35 Days       1000
# 2     Java  15000       NaN        800
# 3   Python  15000   30 Days        500
# 4      PHP  18000   30 Days        800

# %%
# Read Multiple sheets
dict_df = pd.read_excel(excel_path,
                   sheet_name=["Sheet1","Sheet2"])

# Get DataFrame from Dict
course_df = dict_df.get("Sheet1")
course_updated_df = dict_df.get("Sheet2")

# Print DataFrame's
print(course_df)
print(course_updated_df)
# Out:
#   Courses     Fee Duration   Discount
# 0    Spark  25000   50 Days       2000
# 1   Pandas  20000   35 Days       1000
# 2     Java  15000       NaN        800
# 3   Python  15000   30 Days        500
# 4      PHP  18000   30 Days        800
#   Courses     Fee Duration   Discount
# 0    Spark  25000   50 Days       2000
# 1   Pandas  20000   35 Days       1000
# 2     Java  15000   30 Days        700
# 3   Python  15000   30 Days        500
# 4      PHP  18000   30 Days        800

# %%
# Read excel by skipping columns
df2 = pd.read_excel(excel_path, usecols=[0,2])
print(df2)
# Out:
#   Courses  Duration
# 0    Spark   50 Days
# 1   Pandas   35 Days
# 2     Java       NaN
# 3   Python   30 Days
# 4      PHP   30 Days

# %%
# Skip columns by range
df2 = pd.read_excel(excel_path, usecols='B:D')
print(df2)
# Out:
#      Fee Duration   Discount
# 0  25000   50 Days       2000
# 1  20000   35 Days       1000
# 2  15000       NaN        800
# 3  15000   30 Days        500
# 4  18000   30 Days        800

# %%
# Read excel file by skipping rows
df2 = pd.read_excel(excel_path, skiprows=2)
print(df2)
# Out:
#    Pandas  20000  35 Days  1000
# 0    Java  15000      NaN   800
# 1  Python  15000  30 Days   500
# 2     PHP  18000  30 Days   800

# %%
# Using skiprows to skip rows
df2 = pd.read_excel(excel_path,
                   skiprows=[1,3])
print(df2)
# Out:
#   Courses     Fee Duration   Discount
# 0   Pandas  20000   35 Days       1000
# 1   Python  15000   30 Days        500
# 2      PHP  18000   30 Days        800

# %%
# Using skiprows with lambda
df2 = pd.read_excel(excel_path,
                   skiprows=lambda x: x in [1,3])
print(df2)
# Out:
#   Courses     Fee Duration   Discount
# 0   Pandas  20000   35 Days       1000
# 1   Python  15000   30 Days        500
# 2      PHP  18000   30 Days        800

# %% [markdown]
# ## Json format

# %%
# Read json from String
json_str = '{"Courses":{"r1":"Spark"},"Fee":{"r1":"25000"},"Duration":{"r1":"50 Days"}}'
df = pd.read_json(json_str)
print(df)
# Out:
#    Courses    Fee Duration
# r1   Spark  25000  50 Days
# /tmp/ipython-input-1090489127.py:3: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(json_str)

# %%
# Read json from String
json_str = '[{"Courses":"Spark","Fee":"25000","Duration":"50 Days","Discount":"2000"}]'
df = pd.read_json(json_str, orient='records')
print(df)
# Out:
#   Courses    Fee Duration  Discount
# 0   Spark  25000  50 Days      2000
# /tmp/ipython-input-1303048674.py:3: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(json_str, orient='records')

# %%
json_file = "/content/GDrive/MyDrive/COS3302/data_files/courses_data.json"
df = pd.read_json(json_file)
print(df)
# Out:
#   Courses    Fee Duration
# 0   Spark  25000  50 Days
# 1  Pandas  20000  35 Days
# 2    Java  15000

# %%
# Read JSON file with records orient
df = pd.read_json("/content/GDrive/MyDrive/COS3302/data_files/courses.json", orient='records')
print(df)
# Out:
#   Courses    Fee Duration  Discount
# 0   Spark  25000  50 Days      2000
# 1  Pandas  20000  35 Days      1000
# 2    Java  15000                800

# %% [markdown]
# ## CSV format (exercise)

# %% [markdown]
# # Basic information

# %%
c_path = '/content/GDrive/MyDrive/COS3302/data_files/courses.csv'
df = pd.read_csv(c_path,names=columns,header=None)

# %%
df.head()
# Out:
#   courses  course_fee course_duration  course_discount
# 0   Spark       25000         50 Days             2000
# 1  Pandas       20000         35 Days             1000
# 2    Java       15000             NaN              800
# 3  Python       15000         30 Days              500
# 4     PHP       18000         30 Days              800

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   courses          5 non-null      object
#  1   course_fee       5 non-null      int64
#  2   course_duration  4 non-null      object
#  3   course_discount  5 non-null      int64
# dtypes: int64(2), object(2)
# memory usage: 292.0+ bytes

# %%
df.describe()['course_fee']
# Out:
# count        5.000000
# mean     18600.000000
# std       4159.326869
# min      15000.000000
# 25%      15000.000000
# 50%      18000.000000
# 75%      20000.000000
# max      25000.000000
# Name: course_fee, dtype: float64

# %% [markdown]
# # **Wheat Seed Detection**

# %%
column = ['Area','Perimeter','Compactness','Length_of_kernel',
              'Width_of_kernel','Asymmetry_coefficient','Length_of_kernel_groove','Seedtype']
csv_path = '/content/GDrive/MyDrive/COS3302/wheat-seeds.csv'
dfs = pd.read_csv(csv_path,header=None, names=column)
dfs.head()
# Out:
#     Area  Perimeter  Compactness  Length_of_kernel  Width_of_kernel  \
# 0  15.26      14.84       0.8710             5.763            3.312
# 1  14.88      14.57       0.8811             5.554            3.333
# 2  14.29      14.09       0.9050             5.291            3.337
# 3  13.84      13.94       0.8955             5.324            3.379
# 4  16.14      14.99       0.9034             5.658            3.562
#
#    Asymmetry_coefficient  Length_of_kernel_groove  Seedtype
# 0                  2.221                    5.220         1
# 1                  1.018                    4.956         1
# 2                  2.699                    4.825         1
# 3                  2.259                    4.805         1
# 4                  1.355                    5.175         1

# %%
dfs.describe()
# Out:
#              Area   Perimeter  Compactness  Length_of_kernel  Width_of_kernel  \
# count  210.000000  210.000000   210.000000        210.000000       210.000000
# mean    14.847524   14.559286     0.870999          5.628533         3.258605
# std      2.909699    1.305959     0.023629          0.443063         0.377714
# min     10.590000   12.410000     0.808100          4.899000         2.630000
# 25%     12.270000   13.450000     0.856900          5.262250         2.944000
# 50%     14.355000   14.320000     0.873450          5.523500         3.237000
# 75%     17.305000   15.715000     0.887775          5.979750         3.561750
# max     21.180000   17.250000     0.918300          6.675000         4.033000
#
#        Asymmetry_coefficient  Length_of_kernel_groove    Seedtype
# count             210.000000               210.000000  210.000000
# mean                3.700201                 5.408071    2.000000
# std                 1.503557                 0.491480    0.818448
# min                 0.765100                 4.519000    1.000000
# 25%                 2.561500                 5.045000    1.000000
# 50%                 3.599000                 5.223000    2.000000
# 75%                 4.768750                 5.877000    3.000000
# max                 8.456000                 6.550000    3.000000

# %% [markdown]
# ## **Find Value(Range,Max,Min,Mean,Median,Mode,Standard Deviation)**

# %%
def find_statistics(df, col):
    f_min = df[col].min()
    f_max = df[col].max()
    f_sd = df[col].std()
    f_sd = round(f_sd, 3)
    f_mean = df[col].mean()
    f_mean = round(f_mean, 3)
    f_med = df[col].median()
    f_med = round(f_med, 3)
    f_mode = df[col].mode()
    f_mode = round(f_mode, 3)
    range_value = f_max - f_min
    range_value = round(range_value, 3)

    return f"{col} Min: {f_min}\n Max: {f_max}\n Range: {range_value}\n Mean: {f_mean}\n SD: {f_sd}\n Median: {f_med}\n Mode: {f_mode}"

# %% [markdown]
# ### Area Statistics

# %%
area_stats = find_statistics(dfs, 'Area')
print(area_stats)
# Out:
# Area Min: 10.59
#  Max: 21.18
#  Range: 10.59
#  Mean: 14.848
#  SD: 2.91
#  Median: 14.355
#  Mode: 0    11.23
# 1    14.11
# 2    15.38
# Name: Area, dtype: float64

# %% [markdown]
# ### Perimeter Statistics

# %%
perimeter_stats = find_statistics(dfs, 'Perimeter')
print(perimeter_stats)
# Out:
# Perimeter Min: 12.41
#  Max: 17.25
#  Range: 4.84
#  Mean: 14.559
#  SD: 1.306
#  Median: 14.32
#  Mode: 0    13.47
# Name: Perimeter, dtype: float64

# %% [markdown]
# ### Compactness Statistics

# %%
compactness_stats = find_statistics(dfs, 'Compactness')
print(compactness_stats)
# Out:
# Compactness Min: 0.8081
#  Max: 0.9183
#  Range: 0.11
#  Mean: 0.871
#  SD: 0.024
#  Median: 0.873
#  Mode: 0    0.882
# Name: Compactness, dtype: float64

# %% [markdown]
# ### Length of Kernel

# %%
length_of_kernel_stats = find_statistics(dfs, 'Length_of_kernel')
print(length_of_kernel_stats)
# Out:
# Length_of_kernel Min: 4.899
#  Max: 6.675
#  Range: 1.776
#  Mean: 5.629
#  SD: 0.443
#  Median: 5.524
#  Mode: 0    5.236
# 1    5.395
# Name: Length_of_kernel, dtype: float64

# %% [markdown]
# ### Width of Kernel

# %%
width_of_kernel_stats = find_statistics(dfs, 'Width_of_kernel')
print(width_of_kernel_stats)
# Out:
# Width_of_kernel Min: 2.63
#  Max: 4.033
#  Range: 1.403
#  Mean: 3.259
#  SD: 0.378
#  Median: 3.237
#  Mode: 0    3.026
# Name: Width_of_kernel, dtype: float64

# %% [markdown]
# ### Asymmetry Coefficient

# %%
asymmetry_coefficient_stats = find_statistics(dfs, 'Asymmetry_coefficient')
print(asymmetry_coefficient_stats)
# Out:
# Asymmetry_coefficient Min: 0.7651
#  Max: 8.456
#  Range: 7.691
#  Mean: 3.7
#  SD: 1.504
#  Median: 3.599
#  Mode: 0    2.129
# 1    2.221
# 2    2.700
# Name: Asymmetry_coefficient, dtype: float64

# %% [markdown]
# ### Length of Kernel groove

# %%
length_of_kernel_groove_stats = find_statistics(dfs, 'Length_of_kernel_groove')
print(length_of_kernel_groove_stats)
# Out:
# Length_of_kernel_groove Min: 4.519
#  Max: 6.55
#  Range: 2.031
#  Mean: 5.408
#  SD: 0.491
#  Median: 5.223
#  Mode: 0    5.001
# Name: Length_of_kernel_groove, dtype: float64

# %% [markdown]
# ## **Statistics of 3 varities of wheat:Kama, Rosa and, Canadian**

# %%
def create_stat_dict(df):
    stat_dict = {}

    for col in df.columns:
        stat_dict[col] = []

    for col in df.columns:
        stat_dict[col].append((round(df[col].max() - df[col].min(), 3)))
        stat_dict[col].append(df[col].min())
        stat_dict[col].append(df[col].max())
        stat_dict[col].append(round(df[col].mean(), 3))
        stat_dict[col].append(round(df[col].median(), 3))
        stat_dict[col].append(df[col].mode().tolist())
        stat_dict[col].append(round(df[col].std(), 3))

    return stat_dict

# %%
stats_all = create_stat_dict(dfs)

# %%
stat_df = pd.DataFrame.from_dict(stats_all)
stat_label = ["Range", "Min", "Max", "Mean", "Median", "Mode", "SD"]
stat_df.index = stat_label
stat_df.head(15)
# Out:
#                          Area Perimeter Compactness Length_of_kernel  \
# Range                   10.59      4.84        0.11            1.776
# Min                     10.59     12.41      0.8081            4.899
# Max                     21.18     17.25      0.9183            6.675
# Mean                   14.848    14.559       0.871            5.629
# Median                 14.355     14.32       0.873            5.524
# Mode    [11.23, 14.11, 15.38]   [13.47]    [0.8823]   [5.236, 5.395]
# SD                       2.91     1.306       0.024            0.443
#
#        Width_of_kernel Asymmetry_coefficient Length_of_kernel_groove  \
# Range            1.403                 7.691                   2.031
# Min               2.63                0.7651                   4.519
# Max              4.033                 8.456                    6.55
# Mean             3.259                   3.7                   5.408
# Median           3.237                 3.599                   5.223
# Mode           [3.026]   [2.129, 2.221, 2.7]                 [5.001]
# SD               0.378                 1.504                   0.491
#
#          Seedtype
# Range           2
# Min             1
# Max             3
# Mean          2.0
# Median        2.0
# Mode    [1, 2, 3]
# SD          0.818

# %%
stat_kama = create_stat_dict(dfs[dfs["Seedtype"] == 1])
stat_rosa = create_stat_dict(dfs[dfs["Seedtype"] == 2])
stat_canadian = create_stat_dict(dfs[dfs["Seedtype"] == 3])

# %% [markdown]
# ### **Statistics of Kama Wheat**

# %%
stat_df = pd.DataFrame.from_dict(stat_kama)
stat_label = ["Range", "Min", "Max", "Mean", "Median", "Mode", "SD"]
stat_df.index = stat_label
stat_df.head(15)
# Out:
#            Area                                          Perimeter  \
# Range      5.85                                               2.83
# Min       11.23                                              12.63
# Max       17.08                                              15.46
# Mean     14.334                                             14.294
# Median   14.355                                              14.32
# Mode    [14.11]  [13.57, 13.85, 14.02, 14.17, 14.21, 14.28, 14....
# SD        1.216                                              0.577
#
#                            Compactness Length_of_kernel  \
# Range                            0.079            1.151
# Min                             0.8392            4.902
# Max                             0.9183            6.053
# Mean                              0.88            5.508
# Median                           0.881            5.534
# Mode    [0.8726, 0.882, 0.888, 0.8923]          [5.395]
# SD                               0.016            0.232
#
#                                           Width_of_kernel  \
# Range                                               0.833
# Min                                                  2.85
# Max                                                 3.683
# Mean                                                3.245
# Median                                              3.244
# Mode    [3.026, 3.113, 3.156, 3.158, 3.199, 3.201, 3.3...
# SD                                                  0.178
#
#        Asymmetry_coefficient Length_of_kernel_groove Seedtype
# Range                   5.92                   1.358        0
# Min                   0.7651                   4.519        1
# Max                    6.685                   5.877        1
# Mean                   2.667                   5.087      1.0
# Median                 2.546                   5.094      1.0
# Mode            [2.129, 2.7]          [4.825, 5.001]      [1]
# SD                     1.174                   0.264      0.0

# %% [markdown]
# ### **Statistics of Rosa Wheat**

# %%
stat_df = pd.DataFrame.from_dict(stat_rosa)
stat_label = ["Range", "Min", "Max", "Mean", "Median", "Mode", "SD"]
stat_df.index = stat_label
stat_df.head(15)
# Out:
#                                        Area Perimeter  \
# Range                                   5.8      2.59
# Min                                   15.38     14.66
# Max                                   21.18     17.25
# Mean                                 18.334    16.136
# Median                                18.72     16.21
# Mode    [15.38, 17.63, 18.72, 18.94, 18.98]   [16.26]
# SD                                    1.439     0.617
#
#                      Compactness       Length_of_kernel  \
# Range                      0.066                  1.312
# Min                       0.8452                  5.363
# Max                       0.9108                  6.675
# Mean                       0.884                  6.148
# Median                     0.883                  6.149
# Mode    [0.8763, 0.8823, 0.9077]  [5.979, 6.037, 6.285]
# SD                         0.016                  0.268
#
#                      Width_of_kernel  \
# Range                          0.802
# Min                            3.231
# Max                            4.033
# Mean                           3.677
# Median                         3.694
# Mode    [3.594, 3.755, 3.769, 3.857]
# SD                             0.186
#
#                                     Asymmetry_coefficient  \
# Range                                                5.21
# Min                                                 1.472
# Max                                                 6.682
# Mean                                                3.645
# Median                                               3.61
# Mode    [1.472, 1.649, 1.738, 1.91, 1.955, 2.068, 2.10...
# SD                                                  1.182
#
#              Length_of_kernel_groove Seedtype
# Range                          1.406        0
# Min                            5.144        2
# Max                             6.55        2
# Mean                           6.021      2.0
# Median                         5.982      2.0
# Mode    [5.795, 5.879, 6.053, 6.185]      [2]
# SD                             0.254      0.0

# %% [markdown]
# ### **Statistics of Canadian Wheat**

# %%
stat_df = pd.DataFrame.from_dict(stat_canadian)
stat_label = ["Range", "Min", "Max", "Mean", "Median", "Mode", "SD"]
stat_df.index = stat_label
stat_df.head(15)
# Out:
#                                       Area              Perimeter  \
# Range                                 2.78                   1.54
# Min                                  10.59                  12.41
# Max                                  13.37                  13.95
# Mean                                11.874                 13.248
# Median                              11.835                  13.25
# Mode    [11.18, 11.23, 11.27, 12.19, 12.7]  [13.05, 13.41, 13.47]
# SD                                   0.723                   0.34
#
#              Compactness Length_of_kernel  \
# Range               0.09            0.642
# Min               0.8081            4.899
# Max               0.8977            5.541
# Mean               0.849             5.23
# Median             0.849            5.224
# Mode    [0.8198, 0.8558]          [5.236]
# SD                 0.022            0.138
#
#                                   Width_of_kernel  \
# Range                                       0.602
# Min                                          2.63
# Max                                         3.232
# Mean                                        2.854
# Median                                      2.835
# Mode    [2.675, 2.763, 2.81, 2.821, 2.911, 2.967]
# SD                                          0.148
#
#                                     Asymmetry_coefficient  \
# Range                                               6.795
# Min                                                 1.661
# Max                                                 8.456
# Mean                                                4.788
# Median                                              4.839
# Mode    [1.661, 2.201, 2.221, 2.3, 2.828, 3.082, 3.26,...
# SD                                                  1.336
#
#        Length_of_kernel_groove Seedtype
# Range                    0.746        0
# Min                      4.745        3
# Max                      5.491        3
# Mean                     5.116      3.0
# Median                   5.091      3.0
# Mode            [5.001, 5.132]      [3]
# SD                       0.162      0.0
